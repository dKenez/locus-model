# %%
from functools import reduce
from io import BytesIO
from pathlib import Path

import networkx as nx
import polars as pl
import psycopg2
from locus.utils.pl_utils import batch_iter
from tqdm import tqdm

# %matplotlib widget

# %%
conn = psycopg2.connect(host="localhost", dbname="ldogi", user="postgres", password="1425869")

# %%
# Open a cursor to perform database operations
cur = conn.cursor()

# Execute a query
cur.execute("SELECT * FROM dataset")

# Retrieve query results
records = cur.fetchall()

# %%
records
# Out:
# []

# %%
PROJECT_ROOT = Path().cwd().parent
PROCESSED_DATA_DIR = PROJECT_ROOT / "data" / "processed"

# %%
df = pl.scan_parquet(PROCESSED_DATA_DIR / "LDoGI/shards/shard_1.parquet")
print(df.head().collect())
c = df.select(pl.len()).collect()["len"][0] # count
c
# Out:
# shape: (5, 4)
# ┌───────┬────────────┬─────────────┬───────────────────────────────────┐
# │ id    ┆ latitude   ┆ longitude   ┆ image                             │
# │ ---   ┆ ---        ┆ ---         ┆ ---                               │
# │ i64   ┆ f64        ┆ f64         ┆ binary                            │
# ╞═══════╪════════════╪═════════════╪═══════════════════════════════════╡
# │ 29999 ┆ -34.574164 ┆ -58.453917  ┆ b"\xff\xd8\xff\xe0\x00\x10JFIF\x… │
# │ 30000 ┆ 47.608571  ┆ -122.340247 ┆ b"\xff\xd8\xff\xe0\x00\x10JFIF\x… │
# │ 30001 ┆ 43.26605   ┆ -79.90498   ┆ b"\xff\xd8\xff\xe0\x00\x10JFIF\x… │
# │ 30002 ┆ 42.267385  ┆ -71.807584  ┆ b"\xff\xd8\xff\xe0\x00\x10JFIF\x… │
# │ 30003 ┆ 57.040974  ┆ 8.495188    ┆ b"\xff\xd8\xff\xe0\x00\x10JFIF\x… │
# └───────┴────────────┴─────────────┴───────────────────────────────────┘
# 30000

# %%
row_iter = df.head().collect().iter_rows(named=True)

# %%
row = next(row_iter)

# %%
row
# Out:
# {'id': 30001,
#  'latitude': 43.26605,
#  'longitude': -79.90498,
#  'image': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\x08\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x01@\x01c\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xf3\xbb\'x\x80bA\xe7\x00U\xcf\xb4\x86\x93\xcc\xb9_\xdc@2\xaaG\xf1\xff\x00\x9f\xe4+:\xd5\xc1\x8c8\xdc\x0bc\x0c;\x0f\xf1\xadIV\x17\x89\xa5\x91\xb1i\t\xc1#\xb9\xc7Q\xeb\x9e\xdf\xfdz\xcd\x9b\xad\x8c-Vq#Is1\xfd\xec\xad\xc2\x93\x92\xa3\xb7\xe9F\x93k\x05\xe5\xc2@Q\xd8\xb8\xc1(\x0fQ\xeb\xedY\xd7\xf3=\xc5\xe1$m?uS\xfb\xa3\xd3\xebL\x8a\xf6\xe2\xda@\xd0Hc+\xc0"\xb4\x8e\x86\x0fS\xa4\xd4\xfc#\x84y\xe0b\x0e\x06\xd4\xc7\x1f\x8drs\xc1-\xb4\xcd\x14\xcb\xb5\xd7\xa8\xcdi/\x88uE\\}\xa5\x88\xcey\x15F\xee\xeeK\xd9\xbc\xe9\xb0\\\x8c\x12\x07Z\xb94\xf6BW!\x04\x8aw\x98\xfe\xa6\x99E@\xcb\xb0\xca\xd2)\x043\x1a\xbb\x1d\xc0\x01U\x90\x82\xbdI\xe9\x8a\xa5h\xb8Ps\xd4\xfeUv\\6\xd3\xdc\x0e\rKe"Rci\x8a\xa3n\xde\xa3\x1e\xd5P0gpH\x01x\xe9\xd6\x9c\xe9\x86\xc9\\\xe4Uhr\x85\xb7\x81\x90i\x01m\x11C\x06lu\xee:T\xc2g\xdd\xb5c8\x03\xaf5\x0c \x1e@\x1c\x1ej\xe6UPn\x00\x9fC\xda\x81\x94\xe5Ig!\xc1\xc8\xe8rz\x1a\xa5*\xba\x9eYI\x07\xb5]iB\xc9\x90\xa0q\xc6\x07\x15\x06\x04\x92\x17\xe3\x9e\xa2\x9a$\xacK\xf9\x7f2\x8e}M*\xc3\xfb\xd0\x8c\x01?\\\n\x9aT \x11\x80W9\xc8\xa6\x80]\x99\xf0Kf\x8b\x81bD\x8dc\x19\x94\xb3`|\xa0w\xf74E\x1e\\`\xe4\x91\xc0\xce*\'\x0cv\x80\x06{\x9c\xd4\xb8\xe8\x19\xf9\xa0d\xb0#3\xa8FUa\x9f\x9a\x9d<\x0f\x04!\x8c\xaaA\xc6?\xbcj\x00\x8a\xaf\xcb\x13\x91\xd4q\x8aR\x00\x05\xc8\xed\xc0\xa41\x8eG\xcb\xd5@\x18\xe4sOiY\x82\x85\x02 \x06\x01\xee}\xcdF\xf7\x01\x7f\x87\x9e\xf8\xa8\x1eb\xe7\xb8\xa6K,Ip\x1eA,\x8c\xef\'rj\x03q&\xe2T\x90*-\xdf\x8d(\x05\x86~Q\xf54\xc4?\xcepI\xc8\xe6\xa3\xdf\xeazzRm\xf7\x07\xe9M\x03\xbfj`[H\xe3\xda\xa5\x9dF}9?\x95W\x91\xc0?)\xe0w5\x1b\xc8\x14\r\xbdj\x0c3\x91\xd4\xe6\x80\'7\x1c`\x12Oj\xd3\xd1\xac/\xb5+\xa0--%\x9d\xd7\x19\x08\x9b\x82\xfag\x8c~u6\x8d\xa7i\xcf\xa7Is}tam\xc0"\xe3\xaf\xae*\xfe\x83\xe2-F\xda\xcem.\xc8\xac0H\xe5\xdeT\x18s\xdb\x93\xfez\xd4\xdcv:\xbd\x0f\xe1\xde\xa5\x7fv-\xa5h`\x12Dw\xc8N\xe0\x98\xe0\x81\x81\x8d\xc7\xeb\xebK\xe2m\x1f\xc3\xde\x1e\x92=2\x08\xa5y\xd0fk\xa2\xdc\xf3\xd3\x00q\x8fj\xcf\xf0\xee\xbf\xa8\xdax\x9fO\x10\xc9%\xc6&\x11\xa4N\xe4\xa9\xdcpx\xf5\xe7\xadv\x9e8\xf0\xfd\xb4\xfe!y\xa5$\x89#\x1c\x0e\xc7\xbd\\.\xc6\xcf.\xbb\xb7\x8e\xd2g\xf2\xdc\xcd\t\xff\x00W&~\x9e\x95{L\xb4\x9a\xee\xce\xe2.b\x9d\xc8\xd8\xeeH\xca\xe7\xa0\xfc\xaa\ ...

# %%
# Latitude, longitude, and other data



latitude = row["latitude"]  # Replace with actual latitude
longitude = row["longitude"]  # Replace with actual longitude

# Create a BytesIO object to handle the binary data
binary_io = BytesIO(row["image"])

# %%
# Prepare an INSERT statement with parameters for latitude, longitude, and binary data
insert_str = "INSERT INTO dataset (latitude, longitude, image) VALUES (%s, %s, %s);"

# %%
# Execute the query
cur.execute(insert_str, (latitude, longitude, psycopg2.Binary(binary_io.read())))

# Commit the transaction
conn.commit()

# %%
cur.execute("SELECT * FROM dataset;")

# Retrieve query results
records = cur.fetchall()
print(records)
# Out:
# [(1, -34.574165, -58.45392, <memory at 0x7fe9201d6680>), (2, 47.60857, -122.34025, <memory at 0x7fe9201d6440>)]
