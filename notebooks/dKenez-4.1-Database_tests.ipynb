# %%
from functools import reduce
from io import BytesIO
from pathlib import Path

import networkx as nx
import polars as pl
import psycopg2
from locus.utils.pl_utils import batch_iter
from tqdm import tqdm

# %matplotlib widget

# %%
conn = psycopg2.connect(host="localhost", dbname="ldogi", user="postgres", password="1425869")

# %%
# Open a cursor to perform database operations
cur = conn.cursor()

# Execute a query
cur.execute("SELECT * FROM dataset")

# Retrieve query results
records = cur.fetchall()

# %%
records
# Out:
# []

# %%
PROJECT_ROOT = Path().cwd().parent
PROCESSED_DATA_DIR = PROJECT_ROOT / "data" / "processed"

# %%
df = pl.scan_parquet(PROCESSED_DATA_DIR / "LDoGI/shards/shard_1.parquet")
print(df.head().collect())
c = df.select(pl.len()).collect()["len"][0] # count
c
# Out:
# shape: (5, 4)
# ┌───────┬────────────┬─────────────┬───────────────────────────────────┐
# │ id    ┆ latitude   ┆ longitude   ┆ image                             │
# │ ---   ┆ ---        ┆ ---         ┆ ---                               │
# │ i64   ┆ f64        ┆ f64         ┆ binary                            │
# ╞═══════╪════════════╪═════════════╪═══════════════════════════════════╡
# │ 29999 ┆ -34.574164 ┆ -58.453917  ┆ b"\xff\xd8\xff\xe0\x00\x10JFIF\x… │
# │ 30000 ┆ 47.608571  ┆ -122.340247 ┆ b"\xff\xd8\xff\xe0\x00\x10JFIF\x… │
# │ 30001 ┆ 43.26605   ┆ -79.90498   ┆ b"\xff\xd8\xff\xe0\x00\x10JFIF\x… │
# │ 30002 ┆ 42.267385  ┆ -71.807584  ┆ b"\xff\xd8\xff\xe0\x00\x10JFIF\x… │
# │ 30003 ┆ 57.040974  ┆ 8.495188    ┆ b"\xff\xd8\xff\xe0\x00\x10JFIF\x… │
# └───────┴────────────┴─────────────┴───────────────────────────────────┘
# 30000

# %%
row_iter = df.head().collect().iter_rows(named=True)

# %%
row = next(row_iter)

# %%
row
# Out:
# {'id': 30000,
#  'latitude': 47.608571,
#  'longitude': -122.340247,
#  'image': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\x08\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x01@\x01\xaa\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xf4y\xfciw\xa8?\x93\xa1\xd83\x03\xc7\x9f8\xc0\xfa\x81V\xed|3-\xeb\xad\xd6\xb7w%\xd3\xf5\x11\x93\x84_\xa0\xe9[v\x96p\xc3\x12\xa4\x16\xea\x88:\x121Qj\x1a\xbe\x9b\xa5\x80o.G\x98~\xecK\xcb\x1f\xa2\x8a\xe3\xe5\x94\xb5\x9b\xb27n1\xd2\x1b\x96\xad\xed\xe2\xb6P\x96\xb0\xaa\xa7L(\xc0\xa2\xea\xea\xde\xce#%\xdd\xc2D\xbe\xe7\x19\xff\x00\x1a\xc7\x1a\x86\xb3\xab\x8cX\xdb\x8b\x1bs\xd2i\x86\\\x8fa\xd0T\x96\xbe\x1d\xb6\xb7\x9b\xed\x17\x92\xc9ys\xfd\xf9\x8e\xec}\x05\nQ\x8f\xc0\xae\'\x1f\xe6\x7f\xe6;\xfbZ\xee\xf4\xf9zU\x91\t\xday\xc6\xd5\xfc\x07SL\xff\x00\x84{\xedN&\xd5\xef$\xba`r#\xce\xd8\xc7\xd0V\xcbH\xb1G\xb9\x99"\x89G,\xc7\x18\xac\x83\xae$\xd2\x98\xb4\xbby/e\xce\x0c\x87\x88\xc7\xfc\x0b\xfc*\x9a\xbf\xc6\xc4\x9b\xfb(\xd5\x8a4\x821\x1d\xbc+\x1c`u#\x03\xf2\xaa3\xea\xf6\xab)\x86-\xf7\xb7\x03\xfeY\xc22\x01\xf7=\x05E&\x9b=\xccf]f\xfb\x11\x0eL1\x1d\x91\x8f\xa9\xeak\x1a\xe7\xc6ZF\x96\x9fd\xd1mM\xe4\x83\x80!\x18A\xf5n\xff\x00\x85U\xed\xa6\xdf\xd7`\xb5\xfc\xff\x00\xae\xe6\xf7\xd9\xf5+\xe1\x9b\xb9\xc5\x9c?\xf3\xce\x03\xf3c\xdd\xbf\xc2\xb2/<M\xe1\xef\r\x87\x82\xdb\xfd"\xeb\xbaC\xf3\xb1?\xed5aI\x17\x89\xfcP\xd8\xb8\x9d\xad\xed\x98\xff\x00\xa8\xb7\xca\x8c{\x9e\xa6\xb74\xaf\x01\xd9\xd9\xa8i\x80\'\xb8\x1f\xe3T\xa3\'\xe5\xeb\xb9Z-\xff\x00\x03\x85\xf16\xb3\xafx\x9e\x00\r\xb4pY\xc6\xdb\xd6 2\xc7\xdc\xb7\xd2\xbc\xe6ky>\xc7\xa8\tT\x86w\x8f\x19\xf6\xcd}H\x9a]\xa46\xcf\x0cp"\xab)S\xc7$\x1a\xf0_\x14\xe92Z\\\xdc\xdb\xa0\x1b\xd6L\x1c\xf4 \x1a\x89\xd3KTTf\x9e\x88\xf3\xa3j\x07ji\x80\x00k^XH8e\xc1\xaa\xcd\x17\xb5cstg\x18GNi\xbeN\x062j\xfbE\x8a\x8c\xa5\x03)4$\x83\x83\xd6\x9aa}\xa0dU\xd2\x94\xd2\xb4\\\n-\x1c\x80t\xefLe\x93\x07\x0bW\xc8\xa6\x85\xa7q\x10\xc7\xb9l\xdf \xe4\xe3\xf9\x8a\xae\xcd\x93\xdf\xadh\xa0\xccR}@\xa6m\xf6\xa1\xd8J\xe5\x00\xf9<\x9a\x91\\U\x93\x12\x93\x92\xa3\xf2\xa40\xa1\x18\xdbI\xd8i\x95wp[\xf0\x14\x89\x92\xc5\x83\x11\x8e\xe2\xa7\xf2\x13\x18\xe4P \x01p\x18\xf3N\xe9l\'\xa9\xa3\xa3\xf8\x9fY\xd1%i,/Z2\xe3k\x06P\xc0\x8f\xa1\x15\xd2A\xf1g\xc4q\x80%\x16s\x7f\xbd\x0e\x0f\xe8Eq>F\x06\x03~\x94\xc3\x0b\xf3\xc84\xdbOq\xa6\xd6\xc7\xa6\xc1\xf1\x86\xed\x00{\x8d&\xdd\xc1\xe0\xf9r\xb2\xf4\xfa\x83\xebZ\xf6\x7f\x19\xb4\xb4q\xe7\xe9wp\xff\x00\xd7\'V\xff\x00\n\xf1\xc3\ ...

# %%
# Latitude, longitude, and other data



latitude = row["latitude"]  # Replace with actual latitude
longitude = row["longitude"]  # Replace with actual longitude

# Create a BytesIO object to handle the binary data
binary_io = BytesIO(row["image"])

# %%
# Prepare an INSERT statement with parameters for latitude, longitude, and binary data
insert_str = "INSERT INTO dataset (latitude, longitude, image) VALUES (%s, %s, %s);"

# %%
# Execute the query
cur.execute(insert_str, (latitude, longitude, psycopg2.Binary(binary_io.read())))

# Commit the transaction
conn.commit()

# %%
cur.execute("SELECT * FROM dataset;")

# Retrieve query results
records = cur.fetchall()
print(records)
# Out:
# [(1, -34.574165, -58.45392, <memory at 0x7fe9201d6680>), (2, 47.60857, -122.34025, <memory at 0x7fe9201d6440>)]
